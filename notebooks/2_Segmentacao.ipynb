# %% [markdown]
# ### Segmentação
#
# A análise RFM é uma técnica de segmentação do comportamento do cliente baseada em dados.
#
# RFM significa **recência**, **frequência** e **valor monetário**.
#
# O objetivo desta análise é segmentar os clientes com base em quando foi sua última compra, com que frequência eles compraram no passado e quanto gastaram no total.
#
# Embora a análise RFM tenha nascido na mala direta, é uma ferramenta poderosa para as lojas de comércio eletrônico.

# %%
import pandas as pd

# %%
df = pd.read_pickle('../data/prep/dataset_ecommerce.pkl')
df.shape
# Out:
# (397430, 18)

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'InvoiceStatus',
#        'InvoiceDateTime', 'InvoiceYearMonth', 'TotalPrice', 'QuantityZScore',
#        'QuantityOutlier', 'UnitPriceZScore', 'UnitPriceOutlier',
#        'TotalPriceZScore', 'TotalPriceOutlier'],
#       dtype='object')

# %% [markdown]
# **Modelagem**

# %%
dt_final = df['InvoiceDate'].max()

rfm = df.groupby(['CustomerID']).agg({
    'InvoiceDate': lambda x: (dt_final - x.max()).days,
    'InvoiceNo': 'count',
    'TotalPrice': 'sum'
})
rfm.rename(columns={'InvoiceDate':'Recency', 'InvoiceNo':'Frequency', 'TotalPrice':'Monetary'}, inplace=True)
